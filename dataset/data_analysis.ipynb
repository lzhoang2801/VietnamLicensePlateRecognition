# %% [markdown]
# # Vietnam License Plate Segment Datasets
#
# Source: https://www.kaggle.com/datasets/duydieunguyen/licenseplates

# %% [markdown]
# ### Download dataset

# %%
import kagglehub
import os

dataset_dir = "licenseplates"
os.environ["KAGGLEHUB_CACHE"] = dataset_dir

path = kagglehub.dataset_download("duydieunguyen/licenseplates")

print("Path to dataset files:", path)
