# %%
import cv2
import matplotlib.pyplot as plt
import os

os.chdir("..")

# %%
image_path = "dataset/test.png"
image = cv2.imread(image_path)
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
#cv2.imwrite("test.png", gray_image)

# %%
plt.imshow(gray_image, cmap='gray')
plt.show()

# %%
from scripts.feature_extraction import extract_hog_features
from scripts.image_preprocessing import deskew

# %%
resized_image = cv2.resize(gray_image, (28, 28))
#if resized_image.max() > 127:
#    resized_image = 255 - resized_image
deskewed_image = deskew(resized_image, (28, 28))
features = extract_hog_features(deskewed_image)

# %%
plt.imshow(deskewed_image, cmap='gray')
plt.show()

# %%
import pickle
model = pickle.load(open("models/hog_svm.pkl", "rb"))

# %%
predicted_class = model.predict([features])
print(predicted_class)
# Out:
# [28]
